# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaomiew/DWDM21/blob/main/Project_%E0%B8%A5%E0%B9%88%E0%B8%B2%E0%B8%AA%E0%B8%B8%E0%B8%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ส่วนของการ Import
import os

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/DWDM_Project' #กำหนด path ของโฟลเดอร์ที่ Data อยู่

# %% [markdown]
# ##ที่มาของข้อมูลสถานีรับส่งผู้โดยสารการรถไฟเเห่งประเทศไทย
#
# https://data.go.th/dataset/station

# %%
data_st = pd.read_csv(os.path.join(path,'data_station.csv')) #กำหนดตัวแปร data_st เป็นข้อมูลของสถานีรถไฟแต่ละสถานี
data_st #เรียกดูตารางของสถานีรถไฟแต่ละสถานี
# Out:
#       id  station_code           name  ... active giveway dual_track
# 0      1          1001        กรุงเทพ  ...      1       1          1
# 1      2          1002          ยมราช  ...      1       1          1
# 2      3          1004         สามเสน  ...      1       1          1
# 3      4          1006     ประดิพัทธ์  ...      1       1          1
# 4      5          1007  ชุมทางบางซื่อ  ...      1       1          1
# ..   ...           ...            ...  ...    ...     ...        ...
# 677  678          5025       บางโทรัด  ...      1       0          0
# 678  679          5026      บ้านกาหลง  ...      1       0          0
# 679  680          5027     บ้านนาขวาง  ...      1       0          0
# 680  681          5028      บ้านนาโคก  ...      1       0          0
# 681  682          5029       เขตเมือง  ...      1       0          0
#
# [682 rows x 17 columns]

# %% [markdown]
# ##ที่มาของข้อมูลขบวนรถไฟสำหรับรับ-ส่งผู้โดยสาร
#
# https://data.go.th/dataset/train

# %%
data_t = pd.read_csv(os.path.join(path,'data_train.csv')) #กำหนดตัวแปร data_t เป็นข้อมูลของรถไฟ
data_t #เรียกดูตารางข้อมูลรถไฟ
# Out:
#      Zone  goback   Num  ...            NameStEng            NameStEng_L  Service
# 0       1       1   0.0  ...              Bangkok       Ban Plu Ta Luang    False
# 1       1       1   1.0  ...              Bangkok      Bang Sue Junction     True
# 2       1       1   1.0  ...             Makkasan              Hua Takhe    False
# 3       1       1   2.0  ...              Bangkok      Bang Sue Junction     True
# 4       1       1   4.0  ...              Bangkok       Ban Plu Ta Luang    False
# ..    ...     ...   ...  ...                  ...                    ...      ...
# 229     5       2  26.0  ...              Nam Tok              Thon Buri    False
# 230     5       2  27.0  ...  Prachuap Khiri Khan              Thon Buri    False
# 231     5       2  28.0  ...            Lang Suan              Thon Buri    False
# 232     5       2  29.0  ...              Nam Tok              Thon Buri    False
# 233     5       2  30.0  ...              Nam Tok  Nong Pla Duk Junction    False
#
# [234 rows x 12 columns]

# %% [markdown]
# ##ที่มาของข้อมูล railstation
#
# https://datagov.mot.go.th/dataset/train-station

# %%
data_rst = pd.read_csv(os.path.join(path,'railstation_new.csv')) #กำหนดตัวแปร data_rst ให้เป็นรางรถไฟ
data_rst #เรียกดูตารางของรางรถไฟ
# Out:
#      OBJECTID                      NAMET  ...           X          Y
# 0           1               บ้านเกาะปริง  ...   99.644994   8.213274
# 1           2                    ห้วยยอด  ...   99.637987   7.785456
# 2           3            โรงเรียนการบิน   ...   99.956660  14.088246
# 3           4                บ้านปลักแรด  ...  100.725785  14.530267
# 4           5                    เด่นชัย  ...  100.046225  17.980781
# ..        ...                        ...  ...         ...        ...
# 677       678  ศูนย์ราชการจังหวัดสระแก้ว  ...  102.138802  13.799641
# 678       679                    ทุ่งทอง  ...   99.638000  13.980168
# 679       680                ตลาดหนองคาย  ...  102.725416  17.878784
# 680       681               แกรนด์ คาแนล  ...  100.608267  13.941516
# 681       682                   หัวลำโพง  ...  100.516732  13.744026
#
# [682 rows x 8 columns]

# %% [markdown]
# ##ที่มาของข้อมูลชื่อตำบล อำเภอ และจังหวัด
#
# https://www.bot.or.th/Thai/Statistics/DataManagementSystem/TempClose/FI_FM1/Code/DocLib_StandardCodeMapping/Location_Postal%20Code.xls

# %%
data_location = pd.read_csv(os.path.join(path,'Location_Postal_Code.csv')) ## นำเข้าข้อมูลชื่อตำบล อำเภอ และจังหวัด
data_location  ##เรียกดูข้อมูลชื่อตำบล อำเภอ และจังหวัด
# Out:
#       Location Code   จังหวัด   เขต/อำเภอ        แขวง/ตำบล  รหัสไปรษณีย์
# 0            100101   กรุงเทพ      พระนคร  พระบรมมหาราชวัง         10200
# 1            100102   กรุงเทพ      พระนคร   วังบูรพาภิรมย์         10200
# 2            100103   กรุงเทพ      พระนคร       วัดราชบพิธ         10200
# 3            100104   กรุงเทพ      พระนคร      สำราญราษฎร์         10200
# 4            100105   กรุงเทพ      พระนคร   ศาลเจ้าพ่อเสือ         10200
# ...             ...       ...         ...              ...           ...
# 7421         961203  นราธิวาส       จะแนะ         ผดุงมาตร         96220
# 7422         961204  นราธิวาส       จะแนะ        ช้างเผือก         96220
# 7423         961301  นราธิวาส  เจาะไอร้อง              จวบ         96130
# 7424         961302  นราธิวาส  เจาะไอร้อง            บูกิต         96130
# 7425         961303  นราธิวาส  เจาะไอร้อง       มะรือโบออก         96130
#
# [7426 rows x 5 columns]

# %% [markdown]
# #ดูว่าข้อมูลมี data missing

# %%
data_st.isnull()  ##ดูค่า Missing ในตาราง data_st
# Out:
#         id  station_code   name  en_name  ...   long  active  giveway  dual_track
# 0    False         False  False    False  ...  False   False    False       False
# 1    False         False  False    False  ...  False   False    False       False
# 2    False         False  False    False  ...  False   False    False       False
# 3    False         False  False    False  ...  False   False    False       False
# 4    False         False  False    False  ...  False   False    False       False
# ..     ...           ...    ...      ...  ...    ...     ...      ...         ...
# 677  False         False  False    False  ...  False   False    False       False
# 678  False         False  False    False  ...  False   False    False       False
# 679  False         False  False    False  ...  False   False    False       False
# 680  False         False  False    False  ...  False   False    False       False
# 681  False         False  False    False  ...  False   False    False       False
#
# [682 rows x 17 columns]

# %%
data_t.isnull() ##ดูค่า Missing ในตาราง data_t
# Out:
#       Zone  goback    Num  IdTrain  ...  NameSt_L  NameStEng  NameStEng_L  Service
# 0    False   False  False    False  ...     False      False        False    False
# 1    False   False  False    False  ...     False      False        False    False
# 2    False   False  False    False  ...     False      False        False    False
# 3    False   False  False    False  ...     False      False        False    False
# 4    False   False  False    False  ...     False      False        False    False
# ..     ...     ...    ...      ...  ...       ...        ...          ...      ...
# 229  False   False  False    False  ...     False      False        False    False
# 230  False   False  False    False  ...     False      False        False    False
# 231  False   False  False    False  ...     False      False        False    False
# 232  False   False  False    False  ...     False      False        False    False
# 233  False   False  False    False  ...     False      False        False    False
#
# [234 rows x 12 columns]

# %%
data_rst.isnull() ##ดูค่า Missing ในตาราง data_rst
# Out:
#      OBJECTID  NAMET  NAMEE  ProvName  AmpName  TamName      X      Y
# 0       False  False  False     False    False     True  False  False
# 1       False  False  False     False    False    False  False  False
# 2       False  False  False     False    False    False  False  False
# 3       False  False  False     False    False    False  False  False
# 4       False  False  False     False    False    False  False  False
# ..        ...    ...    ...       ...      ...      ...    ...    ...
# 677     False  False  False     False    False    False  False  False
# 678     False  False  False     False    False    False  False  False
# 679     False  False  False     False    False    False  False  False
# 680     False  False  False     False    False    False  False  False
# 681     False  False  False     False    False    False  False  False
#
# [682 rows x 8 columns]

# %%
data_location.isnull()  ##ดูค่า Missing ในตาราง data_location
# Out:
#       Location Code  จังหวัด  เขต/อำเภอ  แขวง/ตำบล  รหัสไปรษณีย์
# 0             False    False      False      False         False
# 1             False    False      False      False         False
# 2             False    False      False      False         False
# 3             False    False      False      False         False
# 4             False    False      False      False         False
# ...             ...      ...        ...        ...           ...
# 7421          False    False      False      False         False
# 7422          False    False      False      False         False
# 7423          False    False      False      False         False
# 7424          False    False      False      False         False
# 7425          False    False      False      False         False
#
# [7426 rows x 5 columns]

# %% [markdown]
# #สรุปข้อมูลเป็นรายคอลลัมม์ว่ามี missing

# %%
data_st.isnull().any()  ##ดูค่า Missing รายคอลัมน์ของตาราง data_st
# Out:
# id                 False
# station_code       False
# name               False
# en_name            False
# th_short           False
# en_short            True
# chname              True
# controldivision    False
# exact_km           False
# exact_distance     False
# km                 False
# class              False
# lat                False
# long               False
# active             False
# giveway            False
# dual_track         False
# dtype: bool

# %%
data_t.isnull().any() ##ดูค่า Missing รายคอลัมน์ของตาราง data_t
# Out:
# Zone           False
# goback         False
# Num            False
# IdTrain        False
# NameFee        False
# StStart        False
# NameSt         False
# StFinal        False
# NameSt_L       False
# NameStEng      False
# NameStEng_L    False
# Service        False
# dtype: bool

# %%
data_rst.isnull().any() ##ดูค่า Missing รายคอลัมน์ของตาราง data_rst
# Out:
# OBJECTID    False
# NAMET       False
# NAMEE       False
# ProvName    False
# AmpName     False
# TamName      True
# X           False
# Y           False
# dtype: bool

# %%
data_location.isnull().any() ##ดูค่า Missing รายคอลัมน์ของตาราง data_location
# Out:
# Location Code    False
# จังหวัด          False
# เขต/อำเภอ         True
# แขวง/ตำบล        False
# รหัสไปรษณีย์     False
# dtype: bool

# %% [markdown]
# #Drop missing value
# ลบค่าที่เป็น Missing

# %%
data_st = data_st.dropna()  ##ลบค่า Missing ในตราง data_st
data_st  ##เรียกดูตาราง data_st
# Out:
#       id  station_code           name  ... active giveway dual_track
# 0      1          1001        กรุงเทพ  ...      1       1          1
# 1      2          1002          ยมราช  ...      1       1          1
# 2      3          1004         สามเสน  ...      1       1          1
# 3      4          1006     ประดิพัทธ์  ...      1       1          1
# 4      5          1007  ชุมทางบางซื่อ  ...      1       1          1
# ..   ...           ...            ...  ...    ...     ...        ...
# 677  678          5025       บางโทรัด  ...      1       0          0
# 678  679          5026      บ้านกาหลง  ...      1       0          0
# 679  680          5027     บ้านนาขวาง  ...      1       0          0
# 680  681          5028      บ้านนาโคก  ...      1       0          0
# 681  682          5029       เขตเมือง  ...      1       0          0
#
# [679 rows x 17 columns]

# %%
data_rst = data_rst.dropna() ##ลบค่า Missing ในตราง data_rst
data_rst   ##เรียกดูตาราง data_rst
# Out:
#      OBJECTID                      NAMET  ...           X          Y
# 1           2                    ห้วยยอด  ...   99.637987   7.785456
# 2           3            โรงเรียนการบิน   ...   99.956660  14.088246
# 3           4                บ้านปลักแรด  ...  100.725785  14.530267
# 4           5                    เด่นชัย  ...  100.046225  17.980781
# 5           6                บ้านกกกว้าว  ...  100.442303  15.141322
# ..        ...                        ...  ...         ...        ...
# 677       678  ศูนย์ราชการจังหวัดสระแก้ว  ...  102.138802  13.799641
# 678       679                    ทุ่งทอง  ...   99.638000  13.980168
# 679       680                ตลาดหนองคาย  ...  102.725416  17.878784
# 680       681               แกรนด์ คาแนล  ...  100.608267  13.941516
# 681       682                   หัวลำโพง  ...  100.516732  13.744026
#
# [681 rows x 8 columns]

# %%
data_location = data_location.dropna()  ##ลบค่า Missing ในตราง data_location
data_location ##เรียกดูตาราง data_location
# Out:
#       Location Code   จังหวัด   เขต/อำเภอ        แขวง/ตำบล  รหัสไปรษณีย์
# 0            100101   กรุงเทพ      พระนคร  พระบรมมหาราชวัง         10200
# 1            100102   กรุงเทพ      พระนคร   วังบูรพาภิรมย์         10200
# 2            100103   กรุงเทพ      พระนคร       วัดราชบพิธ         10200
# 3            100104   กรุงเทพ      พระนคร      สำราญราษฎร์         10200
# 4            100105   กรุงเทพ      พระนคร   ศาลเจ้าพ่อเสือ         10200
# ...             ...       ...         ...              ...           ...
# 7421         961203  นราธิวาส       จะแนะ         ผดุงมาตร         96220
# 7422         961204  นราธิวาส       จะแนะ        ช้างเผือก         96220
# 7423         961301  นราธิวาส  เจาะไอร้อง              จวบ         96130
# 7424         961302  นราธิวาส  เจาะไอร้อง            บูกิต         96130
# 7425         961303  นราธิวาส  เจาะไอร้อง       มะรือโบออก         96130
#
# [7425 rows x 5 columns]

# %% [markdown]
# #ตรวจสอบเมื่อลบออกไปแล้วตรวจสอบว่ายังไม่ข้อมูลที่หายไปหรือไม่

# %%
data_st.isnull().any()  ##ดูค่า Missing รายคอลัมน์ของตาราง data_st หลังการลบค่า Missing
# Out:
# id                 False
# station_code       False
# name               False
# en_name            False
# th_short           False
# en_short           False
# chname             False
# controldivision    False
# exact_km           False
# exact_distance     False
# km                 False
# class              False
# lat                False
# long               False
# active             False
# giveway            False
# dual_track         False
# dtype: bool

# %%
data_rst.isnull().any()  ##ดูค่า Missing รายคอลัมน์ของตาราง data_rst หลังการลบค่า Missing
# Out:
# OBJECTID    False
# NAMET       False
# NAMEE       False
# ProvName    False
# AmpName     False
# TamName     False
# X           False
# Y           False
# dtype: bool

# %%
data_location.isnull().any()  ##ดูค่า Missing รายคอลัมน์ของตาราง data_location หลังการลบค่า Missing
# Out:
# Location Code    False
# จังหวัด          False
# เขต/อำเภอ        False
# แขวง/ตำบล        False
# รหัสไปรษณีย์     False
# dtype: bool

# %% [markdown]
# #Percent of missing data from dropna
#
# เปอร์เซ็นต์ข้อมูลที่สูญเสีย

# %%
##ตาราง data_st
st_b = 682
st_a = 679
print(f'before = {st_b} \nafter = {st_a}\nwhich is {100*((st_b-st_a)/st_b)}')
# Out:
# before = 682
# after = 679
# which is 0.43988269794721413

# %% [markdown]
# จากการคำนวณจะเห็นได้ว่าตาราง data_st มีข้อมูลที่สูญเสีย 0.43 %

# %%
##ตาราง data_rst
rst_b = 682
rst_a = 681
print(f'before = {rst_b} \nafter = {rst_a}\nwhich is {100*((rst_b-rst_a)/rst_b)}')
# Out:
# before = 682
# after = 681
# which is 0.1466275659824047

# %% [markdown]
# จากการคำนวณจะเห็นได้ว่าตาราง data_rst มีข้อมูลที่สูญเสีย 0.14 %

# %%
##ตาราง data_location
loca_b = 7426
loca_a = 7425
print(f'before = {loca_b} \nafter = {loca_a}\nwhich is {100*((loca_b-loca_a)/loca_b)}')
# Out:
# before = 7426
# after = 7425
# which is 0.013466199838405602

# %% [markdown]
# จากการคำนวณจะเห็นได้ว่าตาราง data_location มีข้อมูลที่สูญเสีย 0.01 %

# %% [markdown]
# ###ทำการเชื่อม 2 ตารางด้วยการ merge

# %%
merged_data_t_data_st = data_st.merge(data_t,how='right',left_on='station_code',right_on='StFinal') #ทำการเชื่อมตาราง 2 ตาราง คือ data_t และ data_st
merged_data_t_data_st #เรียกตารางที่เชื่อมกันของ 2 ตารางข้างต้น
# Out:
#       id  station_code  ...            NameStEng_L Service
# 0    331          3047  ...       Ban Plu Ta Luang   False
# 1    331          3047  ...       Ban Plu Ta Luang   False
# 2      5          1007  ...      Bang Sue Junction    True
# 3      5          1007  ...      Bang Sue Junction    True
# 4    307          3015  ...              Hua Takhe   False
# ..   ...           ...  ...                    ...     ...
# 229  442          4089  ...              Rachaburi   False
# 230  535          4238  ...     Khiri Ratthanikhom   False
# 231  501          4186  ...               Chumphon   False
# 232  595          4325  ...            Phatthalung   False
# 233  394          4020  ...  Nong Pla Duk Junction   False
#
# [234 rows x 29 columns]

# %% [markdown]
# ###ทำการเชื่อม 3 ตารางเข้าด้วยกัน

# %%
merged_3_tables = merged_data_t_data_st.merge(data_rst,how='left',left_on='NameSt_L',right_on='NAMET') #ทำเชื่อมตารางระหว่าง merged_data_t_data_st และ data_rst
merged_3_tables #เรียกดูตารางที่เชื่อมกันทั้ง 3 ตาราง
# Out:
#       id  station_code              name  ...      TamName           X          Y
# 0    331          3047     บ้านพลูตาหลวง  ...               100.972127  12.705959
# 1    331          3047     บ้านพลูตาหลวง  ...               100.972127  12.705959
# 2      5          1007     ชุมทางบางซื่อ  ...     BANG SUE  100.539150  13.801880
# 3      5          1007     ชุมทางบางซื่อ  ...     BANG SUE  100.539150  13.801880
# 4    307          3015          หัวตะเข้  ...  LAT KRABANG  100.783373  13.728363
# ..   ...           ...               ...  ...          ...         ...        ...
# 229  442          4089           ราชบุรี  ...    NA MUEANG   99.823848  13.530993
# 230  535          4238       คีรีรัฐนิคม  ...                98.947169   9.031225
# 231  501          4186             ชุมพร  ...   THA TAPHAO   99.175901  10.502983
# 232  595          4325            พัทลุง  ...  KHUHA SAWAN  100.085526   7.621134
# 233  394          4020  ชุมทางหนองปลาดุก  ...                99.911118  13.817960
#
# [234 rows x 37 columns]

# %% [markdown]
# ###ทำการเชื่อมตารางทั้งหมดเข้าด้วยกัน

# %%
merged_4_tables =merged_3_tables.merge(data_location,how='left',left_on='AmpName',right_on='เขต/อำเภอ') #ทำการเชื่อมตาราง merged_3_tables และ data_location
merged_4_tables #เรียกดูตารางที่เชื่อมกันทั้ง 4 ตาราง
# Out:
#        id  station_code              name  ... เขต/อำเภอ   แขวง/ตำบล รหัสไปรษณีย์
# 0     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ      สัตหีบ      20180.0
# 1     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ  นาจอมเทียน      20250.0
# 2     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ   พลูตาหลวง      20180.0
# 3     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ     บางเสร่      20250.0
# 4     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ      แสมสาร      20180.0
# ...   ...           ...               ...  ...       ...         ...          ...
# 2169  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง    คุ้งพยอม      70110.0
# 2170  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง  หนองปลาหมอ      70110.0
# 2171  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง     เขาขลุง      70110.0
# 2172  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง     เบิกไพร      70110.0
# 2173  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง   ลาดบัวขาว      70110.0
#
# [2174 rows x 42 columns]

# %% [markdown]
# #ดูค่า missing ของตารางรวม

# %%
merged_4_tables.isnull().any()  ##ดูค่า Missing รายคอลัมน์ของตาราง merged_4_tables
# Out:
# id                 False
# station_code       False
# name               False
# en_name            False
# th_short           False
# en_short           False
# chname             False
# controldivision    False
# exact_km           False
# exact_distance     False
# km                 False
# class              False
# lat                False
# long               False
# active             False
# giveway            False
# dual_track         False
# Zone               False
# goback             False
# Num                False
# IdTrain            False
# NameFee            False
# StStart            False
# NameSt             False
# StFinal            False
# NameSt_L           False
# NameStEng          False
# NameStEng_L        False
# Service            False
# OBJECTID            True
# NAMET               True
# NAMEE               True
# ProvName            True
# AmpName             True
# TamName             True
# X                   True
# Y                   True
# Location Code       True
# จังหวัด             True
# เขต/อำเภอ           True
# แขวง/ตำบล           True
# รหัสไปรษณีย์        True
# dtype: bool

# %% [markdown]
# # **กำจัดค่า Missing**

# %%
merged_4_tables = merged_4_tables.dropna()  #ลบค่า Missing ในตาราง merged_4_tables
merged_4_tables  #เรียกดูตาราง merged_4_tables
# Out:
#        id  station_code              name  ... เขต/อำเภอ   แขวง/ตำบล รหัสไปรษณีย์
# 0     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ      สัตหีบ      20180.0
# 1     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ  นาจอมเทียน      20250.0
# 2     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ   พลูตาหลวง      20180.0
# 3     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ     บางเสร่      20250.0
# 4     331          3047     บ้านพลูตาหลวง  ...    สัตหีบ      แสมสาร      20180.0
# ...   ...           ...               ...  ...       ...         ...          ...
# 2169  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง    คุ้งพยอม      70110.0
# 2170  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง  หนองปลาหมอ      70110.0
# 2171  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง     เขาขลุง      70110.0
# 2172  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง     เบิกไพร      70110.0
# 2173  394          4020  ชุมทางหนองปลาดุก  ...  บ้านโป่ง   ลาดบัวขาว      70110.0
#
# [2088 rows x 42 columns]

# %% [markdown]
# # **Percent of missing data from dropna**
# **เปอร์เซ็นต์ข้อมูลที่สูญเสีย**

# %%
##ตาราง merged_4_tables
merged_4_b = 2174 
merged_4_a = 2088
print(f'before = {merged_4_b} \nafter = {merged_4_a}\nwhich is {100*((merged_4_b-merged_4_a)/merged_4_b)}')
# Out:
# before = 2174
# after = 2088
# which is 3.9558417663293466

# %% [markdown]
# จากการคำนวณจะเห็นได้ว่าตาราง merged_4_tables มีข้อมูลที่สูญเสีย 3.95 %

# %% [markdown]
# # **ดูค่า Missing รายคอลัมน์**

# %%
merged_4_tables.isnull().any()  ##ดูค่า Missing ของตาราง merged_4_tables
# Out:
# id                 False
# station_code       False
# name               False
# en_name            False
# th_short           False
# en_short           False
# chname             False
# controldivision    False
# exact_km           False
# exact_distance     False
# km                 False
# class              False
# lat                False
# long               False
# active             False
# giveway            False
# dual_track         False
# Zone               False
# goback             False
# Num                False
# IdTrain            False
# NameFee            False
# StStart            False
# NameSt             False
# StFinal            False
# NameSt_L           False
# NameStEng          False
# NameStEng_L        False
# Service            False
# OBJECTID           False
# NAMET              False
# NAMEE              False
# ProvName           False
# AmpName            False
# TamName            False
# X                  False
# Y                  False
# Location Code      False
# จังหวัด            False
# เขต/อำเภอ          False
# แขวง/ตำบล          False
# รหัสไปรษณีย์       False
# dtype: bool

# %% [markdown]
# #challenge
# ##จังหวัดที่มีรถไฟขาเข้ามากที่สุด

# %%
data = merged_4_tables[['จังหวัด','NameSt_L','NameFee','StFinal']]  ##เลือกคอลัมน์ที่ต้องการ
data ##แสดงข้อมูลของตารางที่เลือก
# Out:
#       จังหวัด          NameSt_L   NameFee  StFinal
# 0      ชลบุรี     บ้านพลูตาหลวง      เร็ว     3047
# 1      ชลบุรี     บ้านพลูตาหลวง      เร็ว     3047
# 2      ชลบุรี     บ้านพลูตาหลวง      เร็ว     3047
# 3      ชลบุรี     บ้านพลูตาหลวง      เร็ว     3047
# 4      ชลบุรี     บ้านพลูตาหลวง      เร็ว     3047
# ...       ...               ...       ...      ...
# 2169  ราชบุรี  ชุมทางหนองปลาดุก  ท้องถิ่น     4020
# 2170  ราชบุรี  ชุมทางหนองปลาดุก  ท้องถิ่น     4020
# 2171  ราชบุรี  ชุมทางหนองปลาดุก  ท้องถิ่น     4020
# 2172  ราชบุรี  ชุมทางหนองปลาดุก  ท้องถิ่น     4020
# 2173  ราชบุรี  ชุมทางหนองปลาดุก  ท้องถิ่น     4020
#
# [2088 rows x 4 columns]

# %% [markdown]
# # **หาจังหวัดที่มีรถไฟขาเข้ามากที่สุด**

# %%
Top_Prov = data.groupby('จังหวัด').count().sort_values(by=['StFinal'],ascending=False)   ##นำข้อมูล จังหวัด จากตาราง Data โดยพิจารณาจาก StFinal 
Top_Prov  ##เรียกดูตาราง
# Out:
#                  NameSt_L  NameFee  StFinal
# จังหวัด
# อุบลราชธานี           224      224      224
# นครราชสีมา            205      205      205
# ลพบุรี                161      161      161
# ฉะเชิงเทรา            133      133      133
# เชียงใหม่             128      128      128
# หนองคาย               112      112      112
# สระบุรี                98       98       98
# นครศรีธรรมราช          90       90       90
# พิษณุโลก               80       80       80
# สงขลา                  79       79       79
# กรุงเทพ                76       76       76
# สุรินทร์               73       73       73
# สุราษฎร์ธานี           72       72       72
# ยะลา                   56       56       56
# ปราจีนบุรี             55       55       55
# นครสวรรค์              44       44       44
# ชุมพร                  43       43       43
# อุดรธานี               42       42       42
# นครปฐม                 40       40       40
# ราชบุรี                37       37       37
# อุตรดิตถ์              34       34       34
# พระนครศรีอยุธยา        29       29       29
# ตรัง                   29       29       29
# กาญจนบุรี              21       21       21
# สุพรรณบุรี             20       20       20
# แพร่                   19       19       19
# ขอนแก่น                18       18       18
# สุโขทัย                14       14       14
# พัทลุง                 14       14       14
# ประจวบคีรีขันธ์        13       13       13
# พิจิตร                 13       13       13
# ชลบุรี                 10       10       10
# ปทุมธานี                6        6        6

# %%
Top_Prov.shape  ##ดูขนาดของตราง
# Out:
# (33, 3)

# %%
from matplotlib import pyplot as plt  ## เรียกฟังก์ชันในการ Plot กราฟ

# %%
Top_Prov.iloc[-33:,1]  ##ตัดคอมลัมน์
# Out:
# จังหวัด
# อุบลราชธานี        224
# นครราชสีมา         205
# ลพบุรี             161
# ฉะเชิงเทรา         133
# เชียงใหม่          128
# หนองคาย            112
# สระบุรี             98
# นครศรีธรรมราช       90
# พิษณุโลก            80
# สงขลา               79
# กรุงเทพ             76
# สุรินทร์            73
# สุราษฎร์ธานี        72
# ยะลา                56
# ปราจีนบุรี          55
# นครสวรรค์           44
# ชุมพร               43
# อุดรธานี            42
# นครปฐม              40
# ราชบุรี             37
# อุตรดิตถ์           34
# พระนครศรีอยุธยา     29
# ตรัง                29
# กาญจนบุรี           21
# สุพรรณบุรี          20
# แพร่                19
# ขอนแก่น             18
# สุโขทัย             14
# พัทลุง              14
# ประจวบคีรีขันธ์     13
# พิจิตร              13
# ชลบุรี              10
# ปทุมธานี             6
# Name: NameFee, dtype: int64

# %% [markdown]
# # **Plot กราฟ**

# %%
plt.scatter(range(len(Top_Prov.iloc[-33:,1])),Top_Prov.iloc[-33:,1])  ## Plot กราฟ

# %%
plt.scatter(range(len(Top_Prov.iloc[-33:,1])),Top_Prov.iloc[-33:,1],s=10*Top_Prov.iloc[-33:,1],c=['r'])   ## Plot กราฟ โดยขนาดของจุด*แปรผันตรงกับขนาดของข้อมูล

# %%
plt.scatter(range(len(Top_Prov.iloc[-33:,1])),Top_Prov.iloc[-33:,1],s=30*Top_Prov.iloc[-33:,1],c=0.5*Top_Prov.iloc[-33:,1],cmap='cool')  ## Plot กราฟ โดยเปลี่ยนสีจุดตามข้อมูล

# %% [markdown]
# #**สรุป**

# %%
Top_Prov
# Out:
#                  NameSt_L  NameFee  StFinal
# จังหวัด
# อุบลราชธานี           224      224      224
# นครราชสีมา            205      205      205
# ลพบุรี                161      161      161
# ฉะเชิงเทรา            133      133      133
# เชียงใหม่             128      128      128
# หนองคาย               112      112      112
# สระบุรี                98       98       98
# นครศรีธรรมราช          90       90       90
# พิษณุโลก               80       80       80
# สงขลา                  79       79       79
# กรุงเทพ                76       76       76
# สุรินทร์               73       73       73
# สุราษฎร์ธานี           72       72       72
# ยะลา                   56       56       56
# ปราจีนบุรี             55       55       55
# นครสวรรค์              44       44       44
# ชุมพร                  43       43       43
# อุดรธานี               42       42       42
# นครปฐม                 40       40       40
# ราชบุรี                37       37       37
# อุตรดิตถ์              34       34       34
# พระนครศรีอยุธยา        29       29       29
# ตรัง                   29       29       29
# กาญจนบุรี              21       21       21
# สุพรรณบุรี             20       20       20
# แพร่                   19       19       19
# ขอนแก่น                18       18       18
# สุโขทัย                14       14       14
# พัทลุง                 14       14       14
# ประจวบคีรีขันธ์        13       13       13
# พิจิตร                 13       13       13
# ชลบุรี                 10       10       10
# ปทุมธานี                6        6        6

# %% [markdown]
# ### **จากตารางจะเห็นได้ว่า จังหวัดอุบลราชธานีเป็นจังหวัดที่ มีรถไฟขาเข้ามากที่สุด**
